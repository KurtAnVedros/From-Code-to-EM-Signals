# %%
from keras.layers import Input, Dense
from keras.models import Model, Sequential
from keras import regularizers
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn import preprocessing 
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
from keras.models import Model, load_model
from keras.layers import Input,Dense, BatchNormalization #layers of autoencoder
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping #callbacks
from keras import regularizers #regularization
import keras
import sklearn.metrics as metrics #metrics librry

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6574893549695333622
#  xla_global_id: -1]

# %%
def printandwrite(loc, text, firstLine = False):       
    print(text)
    if firstLine:
        sourceFile = open(loc, 'w')
    else:
        sourceFile = open(loc, 'a')
    sourceFile.write(text)
    sourceFile.close()

# %% [markdown]
# # Load Dataset

# %%
load_Folder = "./Datasets/WGN/"

# %% [markdown]
# ## Real normal

# %%
alpha_SNR_30 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_30_MP.npy", allow_pickle=True)
alpha_SNR_25 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_25_MP.npy", allow_pickle=True)
alpha_SNR_20 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_20_MP.npy", allow_pickle=True)
alpha_SNR_15 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_15_MP.npy", allow_pickle=True)
alpha_SNR_10 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_10_MP.npy", allow_pickle=True)

# %%
echo_SNR_50 = np.load("./Datasets/Numpy/WGN/echo_SNR_50_MP.npy", allow_pickle=True)
echo_SNR_40 = np.load("./Datasets/Numpy/WGN/echo_SNR_40_MP.npy", allow_pickle=True)
echo_SNR_30 = np.load("./Datasets/Numpy/WGN/echo_SNR_30_MP.npy", allow_pickle=True)
echo_SNR_25 = np.load("./Datasets/Numpy/WGN/echo_SNR_25_MP.npy", allow_pickle=True)
echo_SNR_20 = np.load("./Datasets/Numpy/WGN/echo_SNR_20_MP.npy", allow_pickle=True)
echo_SNR_15 = np.load("./Datasets/Numpy/WGN/echo_SNR_15_MP.npy", allow_pickle=True)
echo_SNR_10 = np.load("./Datasets/Numpy/WGN/echo_SNR_10_MP.npy", allow_pickle=True)

# %% [markdown]
# ## Real Anomalous

# %%
alpha_sub_SNR_50 = np.load("./Datasets/Numpy/WGN/alpha_sub_SNR_50_MP.npy", allow_pickle=True)
alpha_sub_SNR_40 = np.load("./Datasets/Numpy/WGN/alpha_sub_SNR_40_MP.npy", allow_pickle=True)
alpha_sub_SNR_30 = np.load("./Datasets/Numpy/WGN/alpha_sub_SNR_30_MP.npy", allow_pickle=True)
alpha_sub_SNR_25 = np.load("./Datasets/Numpy/WGN/alpha_sub_SNR_25_MP.npy", allow_pickle=True)
alpha_sub_SNR_20 = np.load("./Datasets/Numpy/WGN/alpha_sub_SNR_20_MP.npy", allow_pickle=True)
alpha_sub_SNR_15 = np.load("./Datasets/Numpy/WGN/alpha_sub_SNR_15_MP.npy", allow_pickle=True)
alpha_sub_SNR_10 = np.load("./Datasets/Numpy/WGN/alpha_sub_SNR_10_MP.npy", allow_pickle=True)

# %%
echo_sub_SNR_50 = np.load("./Datasets/Numpy/WGN/echo_sub_SNR_50_MP.npy", allow_pickle=True)
echo_sub_SNR_40 = np.load("./Datasets/Numpy/WGN/echo_sub_SNR_40_MP.npy", allow_pickle=True)
echo_sub_SNR_30 = np.load("./Datasets/Numpy/WGN/echo_sub_SNR_30_MP.npy", allow_pickle=True)
echo_sub_SNR_25 = np.load("./Datasets/Numpy/WGN/echo_sub_SNR_25_MP.npy", allow_pickle=True)
echo_sub_SNR_20 = np.load("./Datasets/Numpy/WGN/echo_sub_SNR_20_MP.npy", allow_pickle=True)
echo_sub_SNR_15 = np.load("./Datasets/Numpy/WGN/echo_sub_SNR_15_MP.npy", allow_pickle=True)
echo_sub_SNR_10 = np.load("./Datasets/Numpy/WGN/echo_sub_SNR_10_MP.npy", allow_pickle=True)

# %% [markdown]
# # To compare the similarity using euclidean distance, we need the signal data to be the same lenght. As such, we will remove access information at the end as we assume we have knowledge of the length of time the benign program will take.

# %%
def cutToLength(dataset, length):
    new_Dataset = np.zeros((dataset.shape[0],length))
    
    for i in range(dataset.shape[0]):
        temp = dataset[i]
        new_Dataset[i] = temp[:length]
    
    new_Dataset = np.array(new_Dataset)
    return new_Dataset

# %%
alpha_sub_SNR_50 = cutToLength(alpha_sub_SNR_50, 12)
alpha_sub_SNR_40 = cutToLength(alpha_sub_SNR_40, 12)
alpha_sub_SNR_30 = cutToLength(alpha_sub_SNR_30, 12)
alpha_sub_SNR_25 = cutToLength(alpha_sub_SNR_25, 12)
alpha_sub_SNR_20 = cutToLength(alpha_sub_SNR_20, 12)
alpha_sub_SNR_15 = cutToLength(alpha_sub_SNR_15, 12)
alpha_sub_SNR_10 = cutToLength(alpha_sub_SNR_10, 12)
alpha_sub_SNR_5 = cutToLength(alpha_sub_SNR_5, 12)
print(alpha_SNR_20.shape)
print(alpha_sub_SNR_20.shape)

# %%
echo_sub_SNR_50 = cutToLength(echo_sub_SNR_50, 66)
echo_sub_SNR_40 = cutToLength(echo_sub_SNR_40, 66)
echo_sub_SNR_30 = cutToLength(echo_sub_SNR_30, 66)
echo_sub_SNR_25 = cutToLength(echo_sub_SNR_25, 66)
echo_sub_SNR_20 = cutToLength(echo_sub_SNR_20, 66)
echo_sub_SNR_15 = cutToLength(echo_sub_SNR_15, 66)
echo_sub_SNR_10 = cutToLength(echo_sub_SNR_10, 66)
echo_sub_SNR_5 = cutToLength(echo_sub_SNR_5, 66)
print(echo_SNR_20.shape)
print(echo_sub_SNR_20.shape)

# %% [markdown]
# # Method to do anomaly detection

# %%
def test_autoencoder(program_N, program_A, program, SNR, train_amount, test):  
    import matplotlib.pyplot as plt
    
    params = {'legend.fontsize': 50,
              'figure.figsize': (45, 15),
             'axes.labelsize': 60,
             'axes.titlesize':70,
             'xtick.labelsize':50,
             'ytick.labelsize':50,
              'font.weight': "bold",
             'lines.linewidth': 5}
    plt.rcParams.update(params)
    
    # Dataset
    train_N = np.copy(program_N[0:train_amount])
    test_N = np.copy(program_N[2000:3000])
    test_A = np.copy(program_A[0:1000])
    # Create the X_train, X_test, and y_test
    X_train = train_N.astype('float32')
    X_test = np.concatenate((test_N, test_A)).astype('float32')

    zeros = np.repeat(0,test_N.shape[0])
    ones = np.repeat(1,test_A.shape[0])
    y_test = np.concatenate((zeros,ones))

    # Semi-supervised AutoEncoder
    from numpy.random import seed
    seed(4)
    input_dim = X_train.shape[1]

    Input_layer=Input(shape=(input_dim,))


    ## Create model
    Input_layer=Input(shape=(input_dim,))
    #encoder
    encoding_dim = 100
    from keras import initializers
    #init = initializers.VarianceScaling(scale=1.0, mode='fan_in', distribution='normal', seed=42)
    #encoder
    encoder=Dense(units=100,activation='tanh', use_bias=False, 
                  activity_regularizer=regularizers.l1(10e-5))(Input_layer)
    encoder=BatchNormalization()(encoder)
    encoder=Dense(units=int(50), activation='relu')(encoder)
    encoder=Dense(units=int(25), activation='relu')(encoder)

    #decoder
    decoder=Dense(units=int(50), activation='relu')(encoder)
    decoder=Dense(units=int(100), activation='relu')(decoder)
    decoder=Dense(units=input_dim,activation='relu')(decoder)

    #model
    autoencoder=Model(inputs=Input_layer,outputs=decoder)
    encodermodel=Model(inputs=Input_layer,outputs=encoder)

    # Settings for training the model
    epochs= 400
    batch_size=128

    #TensorBoard=TensorBoard(log_dir='./logs',histogram_freq=0,write_grads=True,write_images=True)
    best_weights_filepath = './best_weights.hdf5'

    earlyStopping=EarlyStopping(monitor='val_loss', patience=50, verbose=0, mode='auto')

    saveBestModel = ModelCheckpoint(best_weights_filepath, monitor='val_loss', 
                                    verbose=0, save_best_only=True, mode='auto')

    ## compile and fit the model
    #we use 90% of data for train and 10% for validation
    autoencoder.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001)
                        ,loss='mean_squared_error',metrics=['accuracy'])

    history=autoencoder.fit(X_train,X_train,
                        epochs=epochs,batch_size=batch_size,shuffle=False,
                        validation_split=0.1,verbose=0, 
                        callbacks=[saveBestModel,earlyStopping]).history
    autoencoder.load_weights(best_weights_filepath)

    # Predict
    predictions_AE=autoencoder.predict(X_test)

    # Find the mean square error
    mse=np.mean(np.power(X_test - predictions_AE, 2), axis=1)

    #plotting the history of the model
    plt.figure()
    plt.plot(history['loss'],label='loss')
    plt.legend()
    plt.plot(history['val_loss'],label='validation loss')
    plt.legend()
    plt.title('loss in train and validation split')
    plt.show()

    params = {'legend.fontsize': 50,
              'figure.figsize': (45, 15),
             'axes.labelsize': 60,
             'axes.titlesize':70,
             'xtick.labelsize':50,
             'ytick.labelsize':50,
              'font.weight': "bold",
             'lines.linewidth': 5}
    plt.rcParams.update(params)

    fpr, tpr, tresholds = metrics.roc_curve(y_test, mse)
    scores_AE=[]
    for treshold in tresholds:
        y_hat_AE = (mse > treshold).astype(int)
        scores_AE.append([metrics.recall_score(y_pred=y_hat_AE, y_true=y_test),
                     metrics.precision_score(y_pred=y_hat_AE, y_true=y_test),
                     metrics.fbeta_score(y_pred=y_hat_AE, y_true=y_test, beta=2),
                     metrics.cohen_kappa_score(y1=y_hat_AE, y2=y_test)])

    roc_auc = metrics.auc(fpr, tpr)

    # method I: plt
    import matplotlib.pyplot as plt
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.savefig("./Graphs/12/" + program + "_SNR_" + SNR + "/"+ str(train_amount) + "/ROC_" + program + "_TrainSize_" + str(train_amount) + "_Test_" + str(test) + ".png", bbox_inches='tight')
    plt.show()

    scores_AE = np.array(scores_AE)
    final_tresh = tresholds[scores_AE[:, 2].argmax()]
    y_hat_AE = (mse > final_tresh).astype(int)
    best_score_AE = scores_AE[scores_AE[:, 2].argmax(),:]
    recall_score_AE = best_score_AE[0]
    precision_score_AE = best_score_AE[1]
    fbeta_score_AE = best_score_AE[2]
    cohen_kappa_score_AE = best_score_AE[3]

    params = {'legend.fontsize': 30,
              'figure.figsize': (15, 15),
             'axes.labelsize': 40,
             'axes.titlesize':30,
             'xtick.labelsize':30,
             'ytick.labelsize':30,
              'font.weight': "bold",
             'lines.linewidth': 5}
    plt.rcParams.update(params)



    print('The recall score is": %.3f' % recall_score_AE)
    print('The precision score is": %.3f' % precision_score_AE)
    print('The f2 score is": %.3f' % fbeta_score_AE)
    print('The Kappa score is": %.3f' % cohen_kappa_score_AE)
    target_names = ['class 0 (Normal)', 'class 1 (Fraud)']
    print(classification_report(y_test, y_hat_AE, target_names=target_names))

    cm = pd.crosstab(y_test, y_hat_AE, rownames=['Actual'], colnames=['Predicted'])
    fig, (ax1) = plt.subplots(ncols=1, figsize=(15,15))
    sns.heatmap(cm, 
                xticklabels=['Benign', 'Anomalous'],
                yticklabels=['Benign', 'Anomalous'],
                annot=True,ax=ax1,
                linewidths=.2,linecolor="Darkblue", cmap="Blues", fmt='d', annot_kws={"fontsize":25})
    plt.title('', fontsize=100)
    plt.savefig("./Graphs/12/" + program + "_SNR_" + SNR + "/"+ str(train_amount) + "/CM_" + program + "_TrainSize_" + str(train_amount) + "_Test_" + str(test) + ".png", bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Settings

# %%
program = "Alpha"
SNR = "15"
train_amount = 2000

program_N = np.copy(alpha_SNR_15)
program_A = np.copy(alpha_sub_SNR_15)

test = 0

test_autoencoder(program_N, program_A, program, SNR, train_amount, test)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The recall score is": 0.968
# The precision score is": 0.749
# The f2 score is": 0.914
# The Kappa score is": 0.643
#                   precision    recall  f1-score   support
#
# class 0 (Normal)       0.95      0.68      0.79      1000
#  class 1 (Fraud)       0.75      0.97      0.84      1000
#
#         accuracy                           0.82      2000
#        macro avg       0.85      0.82      0.82      2000
#     weighted avg       0.85      0.82      0.82      2000

# %%
program = "Alpha"
SNR = "15"
train_amount = 2000

program_N = np.copy(alpha_SNR_15)
program_A = np.copy(alpha_sub_SNR_15)

test = 1

test_autoencoder(program_N, program_A, program, SNR, train_amount, test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 SNR = "15"
#       3 train_amount = 2000
# ----> 5 program_N = np.copy(alpha_SNR_15)
#       6 program_A = np.copy(alpha_sub_SNR_15)
#       8 test = 1
#
# NameError: name 'alpha_SNR_15' is not defined

# %%
program = "Alpha"
SNR = "15"
train_amount = 2000

program_N = np.copy(alpha_SNR_15)
program_A = np.copy(alpha_sub_SNR_15)

test = 1

test_autoencoder(program_N, program_A, program, SNR, train_amount, test)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The recall score is": 0.951
# The precision score is": 0.704
# The f2 score is": 0.889
# The Kappa score is": 0.552
#                   precision    recall  f1-score   support
#
# class 0 (Normal)       0.92      0.60      0.73      1000
#  class 1 (Fraud)       0.70      0.95      0.81      1000
#
#         accuracy                           0.78      2000
#        macro avg       0.81      0.78      0.77      2000
#     weighted avg       0.81      0.78      0.77      2000

# %%
program = "Alpha"
SNR = "15"
train_amount = 1500

program_N = np.copy(alpha_SNR_15)
program_A = np.copy(alpha_sub_SNR_15)

test = 0

test_autoencoder(program_N, program_A, program, SNR, train_amount, test)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The recall score is": 0.962
# The precision score is": 0.640
# The f2 score is": 0.874
# The Kappa score is": 0.422
#                   precision    recall  f1-score   support
#
# class 0 (Normal)       0.92      0.46      0.61      1000
#  class 1 (Fraud)       0.64      0.96      0.77      1000
#
#         accuracy                           0.71      2000
#        macro avg       0.78      0.71      0.69      2000
#     weighted avg       0.78      0.71      0.69      2000

# %%
program = "Alpha"
SNR = "15"
train_amount = 1000

program_N = np.copy(alpha_SNR_15)
program_A = np.copy(alpha_sub_SNR_15)

test = 0

test_autoencoder(program_N, program_A, program, SNR, train_amount, test)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The recall score is": 0.970
# The precision score is": 0.632
# The f2 score is": 0.876
# The Kappa score is": 0.405
#                   precision    recall  f1-score   support
#
# class 0 (Normal)       0.94      0.43      0.59      1000
#  class 1 (Fraud)       0.63      0.97      0.77      1000
#
#         accuracy                           0.70      2000
#        macro avg       0.78      0.70      0.68      2000
#     weighted avg       0.78      0.70      0.68      2000

# %%
program = "Alpha"
SNR = "15"
train_amount = 500

program_N = np.copy(alpha_SNR_15)
program_A = np.copy(alpha_sub_SNR_15)

test = 0

test_autoencoder(program_N, program_A, program, SNR, train_amount, test)
# Out:
# 63/63 [==============================] - 0s 3ms/step
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The recall score is": 0.987
# The precision score is": 0.526
# The f2 score is": 0.840
# The Kappa score is": 0.098
#                   precision    recall  f1-score   support
#
# class 0 (Normal)       0.90      0.11      0.20      1000
#  class 1 (Fraud)       0.53      0.99      0.69      1000
#
#         accuracy                           0.55      2000
#        macro avg       0.71      0.55      0.44      2000
#     weighted avg       0.71      0.55      0.44      2000

# %%
program = "Alpha"
SNR = "15"
train_amount = 100

program_N = np.copy(alpha_SNR_15)
program_A = np.copy(alpha_sub_SNR_15)

test = 3

test_autoencoder(program_N, program_A, program, SNR, train_amount, test)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The recall score is": 0.987
# The precision score is": 0.530
# The f2 score is": 0.842
# The Kappa score is": 0.112
#                   precision    recall  f1-score   support
#
# class 0 (Normal)       0.91      0.12      0.22      1000
#  class 1 (Fraud)       0.53      0.99      0.69      1000
#
#         accuracy                           0.56      2000
#        macro avg       0.72      0.56      0.45      2000
#     weighted avg       0.72      0.56      0.45      2000

# %%
program = "Alpha"
SNR = "15"
train_amount = 10

program_N = np.copy(alpha_SNR_15)
program_A = np.copy(alpha_sub_SNR_15)

test = 0

test_autoencoder(program_N, program_A, program, SNR, train_amount, test)
# Out:
# 63/63 [==============================] - 1s 3ms/step
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\vizen\anaconda3\envs\tf_3_10\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The recall score is": 0.998
# The precision score is": 0.506
# The f2 score is": 0.835
# The Kappa score is": 0.022
#                   precision    recall  f1-score   support
#
# class 0 (Normal)       0.92      0.02      0.05      1000
#  class 1 (Fraud)       0.51      1.00      0.67      1000
#
#         accuracy                           0.51      2000
#        macro avg       0.71      0.51      0.36      2000
#     weighted avg       0.71      0.51      0.36      2000
