# %%
from keras.layers import Input, Dense
from keras.models import Model, Sequential
from keras import regularizers
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn import preprocessing 
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
from keras.models import Model, load_model
from keras.layers import Input,Dense, BatchNormalization #layers of autoencoder
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping #callbacks
from keras import regularizers #regularization
import keras
import sklearn.metrics as metrics #metrics librry

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14123164350288826699
#  xla_global_id: -1]

# %%
def printandwrite(loc, text, firstLine = False):       
    print(text)
    if firstLine:
        sourceFile = open(loc, 'w')
    else:
        sourceFile = open(loc, 'a')
    sourceFile.write(text)
    sourceFile.close()

# %% [markdown]
# # Load Dataset

# %%
load_Folder = "./Datasets/WGN/"

# %% [markdown]
# ## Real normal

# %%
alpha_SNR_30 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_30_MP.npy", allow_pickle=True)
alpha_SNR_25 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_25_MP.npy", allow_pickle=True)
alpha_SNR_20 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_20_MP.npy", allow_pickle=True)
alpha_SNR_15 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_15_MP.npy", allow_pickle=True)
alpha_SNR_10 = np.load("../../Datasets/Numpy/WGN/alpha_SNR_10_MP.npy", allow_pickle=True)

# %%
bravo_SNR_30 = np.load("../../Datasets/Numpy/WGN/bravo_SNR_30_MP.npy", allow_pickle=True)
bravo_SNR_25 = np.load("../../Datasets/Numpy/WGN/bravo_SNR_25_MP.npy", allow_pickle=True)
bravo_SNR_20 = np.load("../../Datasets/Numpy/WGN/bravo_SNR_20_MP.npy", allow_pickle=True)
bravo_SNR_15 = np.load("../../Datasets/Numpy/WGN/bravo_SNR_15_MP.npy", allow_pickle=True)
bravo_SNR_10 = np.load("../../Datasets/Numpy/WGN/bravo_SNR_10_MP.npy", allow_pickle=True)

# %%
charlie_SNR_30 = np.load("../../Datasets/Numpy/WGN/charlie_SNR_30_MP.npy", allow_pickle=True)
charlie_SNR_25 = np.load("../../Datasets/Numpy/WGN/charlie_SNR_25_MP.npy", allow_pickle=True)
charlie_SNR_20 = np.load("../../Datasets/Numpy/WGN/charlie_SNR_20_MP.npy", allow_pickle=True)
charlie_SNR_15 = np.load("../../Datasets/Numpy/WGN/charlie_SNR_15_MP.npy", allow_pickle=True)
charlie_SNR_10 = np.load("../../Datasets/Numpy/WGN/charlie_SNR_10_MP.npy", allow_pickle=True)

# %%
delta_SNR_30 = np.load("../../Datasets/Numpy/WGN/delta_SNR_30_MP.npy", allow_pickle=True)
delta_SNR_25 = np.load("../../Datasets/Numpy/WGN/delta_SNR_25_MP.npy", allow_pickle=True)
delta_SNR_20 = np.load("../../Datasets/Numpy/WGN/delta_SNR_20_MP.npy", allow_pickle=True)
delta_SNR_15 = np.load("../../Datasets/Numpy/WGN/delta_SNR_15_MP.npy", allow_pickle=True)
delta_SNR_10 = np.load("../../Datasets/Numpy/WGN/delta_SNR_10_MP.npy", allow_pickle=True)

# %%
echo_SNR_30 = np.load("../../Datasets/Numpy/WGN/echo_SNR_30_MP.npy", allow_pickle=True)
echo_SNR_25 = np.load("../../Datasets/Numpy/WGN/echo_SNR_25_MP.npy", allow_pickle=True)
echo_SNR_20 = np.load("../../Datasets/Numpy/WGN/echo_SNR_20_MP.npy", allow_pickle=True)
echo_SNR_15 = np.load("../../Datasets/Numpy/WGN/echo_SNR_15_MP.npy", allow_pickle=True)
echo_SNR_10 = np.load("../../Datasets/Numpy/WGN/echo_SNR_10_MP.npy", allow_pickle=True)

# %% [markdown]
# ## Real Anomalous

# %%
alpha_sub_SNR_30 = np.load("../../Datasets/Numpy/WGN/alpha_sub_SNR_30_MP.npy", allow_pickle=True)
alpha_sub_SNR_25 = np.load("../../Datasets/Numpy/WGN/alpha_sub_SNR_25_MP.npy", allow_pickle=True)
alpha_sub_SNR_20 = np.load("../../Datasets/Numpy/WGN/alpha_sub_SNR_20_MP.npy", allow_pickle=True)
alpha_sub_SNR_15 = np.load("../../Datasets/Numpy/WGN/alpha_sub_SNR_15_MP.npy", allow_pickle=True)
alpha_sub_SNR_10 = np.load("../../Datasets/Numpy/WGN/alpha_sub_SNR_10_MP.npy", allow_pickle=True)

# %%
bravo_sub_SNR_30 = np.load("../../Datasets/Numpy/WGN/bravo_sub_SNR_30_MP.npy", allow_pickle=True)
bravo_sub_SNR_25 = np.load("../../Datasets/Numpy/WGN/bravo_sub_SNR_25_MP.npy", allow_pickle=True)
bravo_sub_SNR_20 = np.load("../../Datasets/Numpy/WGN/bravo_sub_SNR_20_MP.npy", allow_pickle=True)
bravo_sub_SNR_15 = np.load("../../Datasets/Numpy/WGN/bravo_sub_SNR_15_MP.npy", allow_pickle=True)
bravo_sub_SNR_10 = np.load("../../Datasets/Numpy/WGN/bravo_sub_SNR_10_MP.npy", allow_pickle=True)

# %%
charlie_sub_SNR_30 = np.load("../../Datasets/Numpy/WGN/charlie_sub_SNR_30_MP.npy", allow_pickle=True)
charlie_sub_SNR_25 = np.load("../../Datasets/Numpy/WGN/charlie_sub_SNR_25_MP.npy", allow_pickle=True)
charlie_sub_SNR_20 = np.load("../../Datasets/Numpy/WGN/charlie_sub_SNR_20_MP.npy", allow_pickle=True)
charlie_sub_SNR_15 = np.load("../../Datasets/Numpy/WGN/charlie_sub_SNR_15_MP.npy", allow_pickle=True)
charlie_sub_SNR_10 = np.load("../../Datasets/Numpy/WGN/charlie_sub_SNR_10_MP.npy", allow_pickle=True)

# %%
delta_sub_SNR_30 = np.load("../../Datasets/Numpy/WGN/delta_sub_SNR_30_MP.npy", allow_pickle=True)
delta_sub_SNR_25 = np.load("../../Datasets/Numpy/WGN/delta_sub_SNR_25_MP.npy", allow_pickle=True)
delta_sub_SNR_20 = np.load("../../Datasets/Numpy/WGN/delta_sub_SNR_20_MP.npy", allow_pickle=True)
delta_sub_SNR_15 = np.load("../../Datasets/Numpy/WGN/delta_sub_SNR_15_MP.npy", allow_pickle=True)
delta_sub_SNR_10 = np.load("../../Datasets/Numpy/WGN/delta_sub_SNR_10_MP.npy", allow_pickle=True)

# %%
echo_sub_SNR_30 = np.load("../../Datasets/Numpy/WGN/echo_sub_SNR_30_MP.npy", allow_pickle=True)
echo_sub_SNR_25 = np.load("../../Datasets/Numpy/WGN/echo_sub_SNR_25_MP.npy", allow_pickle=True)
echo_sub_SNR_20 = np.load("../../Datasets/Numpy/WGN/echo_sub_SNR_20_MP.npy", allow_pickle=True)
echo_sub_SNR_15 = np.load("../../Datasets/Numpy/WGN/echo_sub_SNR_15_MP.npy", allow_pickle=True)
echo_sub_SNR_10 = np.load("../../Datasets/Numpy/WGN/echo_sub_SNR_10_MP.npy", allow_pickle=True)

# %% [markdown]
# # To compare the similarity using euclidean distance, we need the signal data to be the same lenght. As such, we will remove access information at the end as we assume we have knowledge of the length of time the benign program will take.

# %%
def cutToLength(dataset, length):
    new_Dataset = np.zeros((dataset.shape[0],length))
    
    for i in range(dataset.shape[0]):
        temp = dataset[i]
        new_Dataset[i] = temp[:length]
    
    new_Dataset = np.array(new_Dataset)
    return new_Dataset

# %% [markdown]
# # alpha

# %%
print(alpha_SNR_30.shape)
# Out:
# (3000, 12)

# %%
print(alpha_sub_SNR_30.shape)
print(alpha_sub_SNR_25.shape)
print(alpha_sub_SNR_20.shape)
print(alpha_sub_SNR_15.shape)
print(alpha_sub_SNR_10.shape)
# Out:
# (1312, 13)
# (1312, 13)
# (1312, 13)
# (1312, 13)
# (1312, 13)

# %%
alpha_sub_SNR_30 = cutToLength(alpha_sub_SNR_30, 12)
alpha_sub_SNR_25 = cutToLength(alpha_sub_SNR_25, 12)
alpha_sub_SNR_20 = cutToLength(alpha_sub_SNR_20, 12)
alpha_sub_SNR_15 = cutToLength(alpha_sub_SNR_15, 12)
alpha_sub_SNR_10 = cutToLength(alpha_sub_SNR_10, 12)
print(alpha_SNR_20.shape)
print(alpha_sub_SNR_20.shape)
# Out:
# (3000, 12)
# (1312, 12)

# %% [markdown]
# # bravo

# %%
print(bravo_SNR_30.shape)
# Out:
# (3000, 26)

# %%
print(bravo_sub_SNR_30.shape)
print(bravo_sub_SNR_25.shape)
print(bravo_sub_SNR_20.shape)
print(bravo_sub_SNR_15.shape)
print(bravo_sub_SNR_10.shape)
# Out:
# (1280, 27)
# (1280, 27)
# (1280, 27)
# (1280, 27)
# (1280, 27)

# %%
bravo_sub_SNR_30 = cutToLength(bravo_sub_SNR_30, 26)
bravo_sub_SNR_25 = cutToLength(bravo_sub_SNR_25, 26)
bravo_sub_SNR_20 = cutToLength(bravo_sub_SNR_20, 26)
bravo_sub_SNR_15 = cutToLength(bravo_sub_SNR_15, 26)
bravo_sub_SNR_10 = cutToLength(bravo_sub_SNR_10, 26)
print(bravo_SNR_20.shape)
print(bravo_sub_SNR_20.shape)
# Out:
# (3000, 26)
# (1280, 26)

# %% [markdown]
# # charlie

# %%
print(charlie_SNR_30.shape)
# Out:
# (3000, 39)

# %%
print(charlie_sub_SNR_30.shape)
print(charlie_sub_SNR_25.shape)
print(charlie_sub_SNR_20.shape)
print(charlie_sub_SNR_15.shape)
print(charlie_sub_SNR_10.shape)
# Out:
# (1280, 40)
# (1280, 40)
# (1280, 40)
# (1280, 40)
# (1280, 40)

# %%
charlie_sub_SNR_30 = cutToLength(charlie_sub_SNR_30, 39)
charlie_sub_SNR_25 = cutToLength(charlie_sub_SNR_25, 39)
charlie_sub_SNR_20 = cutToLength(charlie_sub_SNR_20, 39)
charlie_sub_SNR_15 = cutToLength(charlie_sub_SNR_15, 39)
charlie_sub_SNR_10 = cutToLength(charlie_sub_SNR_10, 39)
print(charlie_SNR_20.shape)
print(charlie_sub_SNR_20.shape)
# Out:
# (3000, 39)
# (1280, 39)

# %% [markdown]
# # delta

# %%
print(delta_SNR_30.shape)
# Out:
# (3000, 50)

# %%
print(delta_sub_SNR_30.shape)
print(delta_sub_SNR_25.shape)
print(delta_sub_SNR_20.shape)
print(delta_sub_SNR_15.shape)
print(delta_sub_SNR_10.shape)
# Out:
# (1312, 51)
# (1312, 51)
# (1312, 51)
# (1312, 51)
# (1312, 51)

# %%
delta_sub_SNR_30 = cutToLength(delta_sub_SNR_30, 50)
delta_sub_SNR_25 = cutToLength(delta_sub_SNR_25, 50)
delta_sub_SNR_20 = cutToLength(delta_sub_SNR_20, 50)
delta_sub_SNR_15 = cutToLength(delta_sub_SNR_15, 50)
delta_sub_SNR_10 = cutToLength(delta_sub_SNR_10, 50)
print(delta_SNR_20.shape)
print(delta_sub_SNR_20.shape)
# Out:
# (3000, 50)
# (1312, 50)

# %% [markdown]
# # echo

# %%
print(echo_SNR_30.shape)
# Out:
# (3000, 66)

# %%
print(echo_sub_SNR_30.shape)
print(echo_sub_SNR_25.shape)
print(echo_sub_SNR_20.shape)
print(echo_sub_SNR_15.shape)
print(echo_sub_SNR_10.shape)
# Out:
# (1408, 67)
# (1408, 67)
# (1408, 67)
# (1408, 67)
# (1408, 67)

# %%
echo_sub_SNR_30 = cutToLength(echo_sub_SNR_30, 66)
echo_sub_SNR_25 = cutToLength(echo_sub_SNR_25, 66)
echo_sub_SNR_20 = cutToLength(echo_sub_SNR_20, 66)
echo_sub_SNR_15 = cutToLength(echo_sub_SNR_15, 66)
echo_sub_SNR_10 = cutToLength(echo_sub_SNR_10, 66)
print(echo_SNR_20.shape)
print(echo_sub_SNR_20.shape)
# Out:
# (3000, 66)
# (1408, 66)

# %% [markdown]
# # Method to do anomaly detection

# %%
import sys
# setting path
sys.path.append('../../')
from Modules.Tests import KNN_Exp

# %% [markdown]
# # alpha

# %% [markdown]
# # Settings

# %%
program_N = alpha_SNR_30
program_A = alpha_sub_SNR_30
SNR = "30"

folder = "./Results/kNN/Alpha_SNR_" + SNR + "/"

NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

# %%
Training_Amount = 2000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "alpha SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "alpha SNR-" +SNR
anomalyInst = "alpha_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: alpha SNR-30 TS-2000
# Size of Training Set: 2000
# Test Set Used: alpha SNR-30 normal along with alpha_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.9985007496251874
# Max f1 score: 0.9985007496251874
# Min f1 score: 0.9985007496251874
# Avg acc score: 0.9985
# Max acc score: 0.9985
# Min acc score: 0.9985
# Avg AUC score: 0.99998
# Max AUC score: 0.99998
# Min AUC score: 0.99998
# Time: 14.019363000057638

# %%
Training_Amount = 1500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "alpha SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "alpha SNR-" +SNR
anomalyInst = "alpha_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: alpha SNR-30 TS-1500
# Size of Training Set: 1500
# Test Set Used: alpha SNR-30 normal along with alpha_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.999
# Max f1 score: 0.999
# Min f1 score: 0.999
# Avg acc score: 0.999
# Max acc score: 0.999
# Min acc score: 0.999
# Avg AUC score: 0.9999855
# Max AUC score: 0.9999855
# Min AUC score: 0.9999855
# Time: 13.630774399964139

# %%
Training_Amount = 1000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "alpha SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "alpha SNR-" +SNR
anomalyInst = "alpha_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: alpha SNR-30 TS-1000
# Size of Training Set: 1000
# Test Set Used: alpha SNR-30 normal along with alpha_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.9985007496251874
# Max f1 score: 0.9985007496251874
# Min f1 score: 0.9985007496251874
# Avg acc score: 0.9985
# Max acc score: 0.9985
# Min acc score: 0.9985
# Avg AUC score: 0.997993
# Max AUC score: 0.997993
# Min AUC score: 0.997993
# Time: 13.525477099930868

# %%
Training_Amount = 500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "alpha SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "alpha SNR-" +SNR
anomalyInst = "alpha_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: alpha SNR-30 TS-500
# Size of Training Set: 500
# Test Set Used: alpha SNR-30 normal along with alpha_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.999
# Max f1 score: 0.999
# Min f1 score: 0.999
# Avg acc score: 0.999
# Max acc score: 0.999
# Min acc score: 0.999
# Avg AUC score: 0.998995
# Max AUC score: 0.998995
# Min AUC score: 0.998995
# Time: 13.523147900006734

# %%
Training_Amount = 100

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "alpha SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "alpha SNR-" +SNR
anomalyInst = "alpha_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: alpha SNR-30 TS-100
# Size of Training Set: 100
# Test Set Used: alpha SNR-30 normal along with alpha_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.9975037443834248
# Max f1 score: 0.9975037443834248
# Min f1 score: 0.9975037443834248
# Avg acc score: 0.9975
# Max acc score: 0.9975
# Min acc score: 0.9975
# Avg AUC score: 0.997987
# Max AUC score: 0.997987
# Min AUC score: 0.997987
# Time: 13.520952100050636

# %%
Training_Amount = 10

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "alpha SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "alpha SNR-" +SNR
anomalyInst = "alpha_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: alpha SNR-30 TS-10
# Size of Training Set: 10
# Test Set Used: alpha SNR-30 normal along with alpha_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.9900199600798403
# Max f1 score: 0.9900199600798403
# Min f1 score: 0.9900199600798403
# Avg acc score: 0.99
# Max acc score: 0.99
# Min acc score: 0.99
# Avg AUC score: 0.9994049999999999
# Max AUC score: 0.9994049999999999
# Min AUC score: 0.9994049999999999
# Time: 14.80211400007829

# %% [markdown]
# # bravo

# %% [markdown]
# # Settings

# %%
program_N = bravo_SNR_30
program_A = bravo_sub_SNR_30
SNR = "30"

folder = "./Results/kNN/bravo_SNR_" + SNR + "/"

NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

# %%
Training_Amount = 2000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "bravo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "bravo SNR-" +SNR
anomalyInst = "bravo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: bravo SNR-30 TS-2000
# Size of Training Set: 2000
# Test Set Used: bravo SNR-30 normal along with bravo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 14.444926300086081

# %%
Training_Amount = 1500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "bravo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "bravo SNR-" +SNR
anomalyInst = "bravo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: bravo SNR-30 TS-1500
# Size of Training Set: 1500
# Test Set Used: bravo SNR-30 normal along with bravo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.815606500022113

# %%
Training_Amount = 1000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "bravo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "bravo SNR-" +SNR
anomalyInst = "bravo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: bravo SNR-30 TS-1000
# Size of Training Set: 1000
# Test Set Used: bravo SNR-30 normal along with bravo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.9995002498750625
# Max f1 score: 0.9995002498750625
# Min f1 score: 0.9995002498750625
# Avg acc score: 0.9995
# Max acc score: 0.9995
# Min acc score: 0.9995
# Avg AUC score: 0.999
# Max AUC score: 0.999
# Min AUC score: 0.999
# Time: 13.608708500047214

# %%
Training_Amount = 500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "bravo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "bravo SNR-" +SNR
anomalyInst = "bravo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: bravo SNR-30 TS-500
# Size of Training Set: 500
# Test Set Used: bravo SNR-30 normal along with bravo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.816500599961728

# %%
Training_Amount = 100

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "bravo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "bravo SNR-" +SNR
anomalyInst = "bravo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: bravo SNR-30 TS-100
# Size of Training Set: 100
# Test Set Used: bravo SNR-30 normal along with bravo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.9995002498750625
# Max f1 score: 0.9995002498750625
# Min f1 score: 0.9995002498750625
# Avg acc score: 0.9995
# Max acc score: 0.9995
# Min acc score: 0.9995
# Avg AUC score: 0.999
# Max AUC score: 0.999
# Min AUC score: 0.999
# Time: 13.615609399974346

# %%
Training_Amount = 10

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "bravo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "bravo SNR-" +SNR
anomalyInst = "bravo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: bravo SNR-30 TS-10
# Size of Training Set: 10
# Test Set Used: bravo SNR-30 normal along with bravo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.902825099998154

# %% [markdown]
# # charlie

# %% [markdown]
# # Settings

# %%
program_N = charlie_SNR_30
program_A = charlie_sub_SNR_30
SNR = "30"

folder = "./Results/kNN/charlie_SNR_" + SNR + "/"

NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

# %%
Training_Amount = 2000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "charlie SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "charlie SNR-" +SNR
anomalyInst = "charlie_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: charlie SNR-30 TS-2000
# Size of Training Set: 2000
# Test Set Used: charlie SNR-30 normal along with charlie_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.695766699966043

# %%
Training_Amount = 1500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "charlie SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "charlie SNR-" +SNR
anomalyInst = "charlie_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: charlie SNR-30 TS-1500
# Size of Training Set: 1500
# Test Set Used: charlie SNR-30 normal along with charlie_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.67364799999632

# %%
Training_Amount = 1000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "charlie SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "charlie SNR-" +SNR
anomalyInst = "charlie_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: charlie SNR-30 TS-1000
# Size of Training Set: 1000
# Test Set Used: charlie SNR-30 normal along with charlie_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.660218099947087

# %%
Training_Amount = 500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "charlie SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "charlie SNR-" +SNR
anomalyInst = "charlie_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: charlie SNR-30 TS-500
# Size of Training Set: 500
# Test Set Used: charlie SNR-30 normal along with charlie_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.834390599979088

# %%
Training_Amount = 100

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "charlie SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "charlie SNR-" +SNR
anomalyInst = "charlie_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: charlie SNR-30 TS-100
# Size of Training Set: 100
# Test Set Used: charlie SNR-30 normal along with charlie_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.871843299944885

# %%
Training_Amount = 10

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "charlie SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "charlie SNR-" +SNR
anomalyInst = "charlie_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: charlie SNR-30 TS-10
# Size of Training Set: 10
# Test Set Used: charlie SNR-30 normal along with charlie_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.708664200035855

# %% [markdown]
# # delta

# %% [markdown]
# # Settings

# %%
program_N = delta_SNR_30
program_A = delta_sub_SNR_30
SNR = "30"

folder = "./Results/kNN/delta_SNR_" + SNR + "/"

NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

# %%
Training_Amount = 2000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "delta SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "delta SNR-" +SNR
anomalyInst = "delta_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: delta SNR-30 TS-2000
# Size of Training Set: 2000
# Test Set Used: delta SNR-30 normal along with delta_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.555165199912153

# %%
Training_Amount = 1500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "delta SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "delta SNR-" +SNR
anomalyInst = "delta_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: delta SNR-30 TS-1500
# Size of Training Set: 1500
# Test Set Used: delta SNR-30 normal along with delta_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.741055700113066

# %%
Training_Amount = 1000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "delta SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "delta SNR-" +SNR
anomalyInst = "delta_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: delta SNR-30 TS-1000
# Size of Training Set: 1000
# Test Set Used: delta SNR-30 normal along with delta_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.929448200040497

# %%
Training_Amount = 500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "delta SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "delta SNR-" +SNR
anomalyInst = "delta_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: delta SNR-30 TS-500
# Size of Training Set: 500
# Test Set Used: delta SNR-30 normal along with delta_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.811386100016534

# %%
Training_Amount = 100

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "delta SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "delta SNR-" +SNR
anomalyInst = "delta_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: delta SNR-30 TS-100
# Size of Training Set: 100
# Test Set Used: delta SNR-30 normal along with delta_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.9995002498750625
# Max f1 score: 0.9995002498750625
# Min f1 score: 0.9995002498750625
# Avg acc score: 0.9995
# Max acc score: 0.9995
# Min acc score: 0.9995
# Avg AUC score: 0.999
# Max AUC score: 0.999
# Min AUC score: 0.999
# Time: 13.684890100033954

# %%
Training_Amount = 10

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "delta SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "delta SNR-" +SNR
anomalyInst = "delta_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: delta SNR-30 TS-10
# Size of Training Set: 10
# Test Set Used: delta SNR-30 normal along with delta_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.710991999949329

# %% [markdown]
# # echo

# %% [markdown]
# # Settings

# %%
program_N = echo_SNR_30
program_A = echo_sub_SNR_30
SNR = "30"

folder = "./Results/kNN/echo_SNR_" + SNR + "/"

NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

# %%
Training_Amount = 2000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "echo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "echo SNR-" +SNR
anomalyInst = "echo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: echo SNR-30 TS-2000
# Size of Training Set: 2000
# Test Set Used: echo SNR-30 normal along with echo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.735468699946068

# %%
Training_Amount = 1500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "echo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "echo SNR-" +SNR
anomalyInst = "echo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: echo SNR-30 TS-1500
# Size of Training Set: 1500
# Test Set Used: echo SNR-30 normal along with echo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.659523000009358

# %%
Training_Amount = 1000

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "echo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "echo SNR-" +SNR
anomalyInst = "echo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: echo SNR-30 TS-1000
# Size of Training Set: 1000
# Test Set Used: echo SNR-30 normal along with echo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.593410700093955

# %%
Training_Amount = 500

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "echo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "echo SNR-" +SNR
anomalyInst = "echo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: echo SNR-30 TS-500
# Size of Training Set: 500
# Test Set Used: echo SNR-30 normal along with echo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 0.9995002498750625
# Max f1 score: 0.9995002498750625
# Min f1 score: 0.9995002498750625
# Avg acc score: 0.9995
# Max acc score: 0.9995
# Min acc score: 0.9995
# Avg AUC score: 0.999
# Max AUC score: 0.999
# Min AUC score: 0.999
# Time: 13.706315399962477

# %%
Training_Amount = 100

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "echo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "echo SNR-" +SNR
anomalyInst = "echo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: echo SNR-30 TS-100
# Size of Training Set: 100
# Test Set Used: echo SNR-30 normal along with echo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.654995099990629

# %%
Training_Amount = 10

NormalTrain = program_N[0:Training_Amount]
NormalTest = program_N[2000:3000]
AnomalyTest = program_A[0:1000]

normalTrainInst = "echo SNR-" + SNR + " TS-" + str(Training_Amount)
normalTestInst = "echo SNR-" +SNR
anomalyInst = "echo_sub SNR-" +SNR

name = normalTrainInst + " vs " + anomalyInst

path = folder + name + "/"

kFold = 1

neighbor = np.array([10])

f1Best, accBest, aucBest = KNN_Exp.runExperiment(NormalTrain, NormalTest, AnomalyTest, normalTrainInst, 
                                                    normalTestInst, anomalyInst, name, path, neighbors = neighbor, numFold = kFold)
# Out:
# Beginning Tests...
# Method: KNN
# Normal Dataset Used: echo SNR-30 TS-10
# Size of Training Set: 10
# Test Set Used: echo SNR-30 normal along with echo_sub SNR-30 anomaly instances
# Size of Test Set: 1000 (normal) 1000 (anomalous)
# Neighbors: 10
# Avg f1 score: 1.0
# Max f1 score: 1.0
# Min f1 score: 1.0
# Avg acc score: 1.0
# Max acc score: 1.0
# Min acc score: 1.0
# Avg AUC score: 1.0
# Max AUC score: 1.0
# Min AUC score: 1.0
# Time: 13.562270099995658
